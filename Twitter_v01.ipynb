# %% [markdown]
# # Downloading and importing necessary packages

# %%
# !pip install bertopic
# Out:
# ...
#   Using cached hdbscan-0.8.28.tar.gz (5.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached umap_learn-0.5.3-py3-none-any.whl
# ...
#   Using cached PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# ...
#   Using cached pynndescent-0.5.7-py3-none-any.whl
# ...
#   Using cached numpy-1.20.3-cp39-cp39-win_amd64.whl (13.7 MB)
# ...
# Failed to build hdbscan
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
# ...

# %%
# !pip install text2emotion
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)

# %%
# !pip install textblob
# !pip install textblob-de
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# ...

# %%
# !pip install germansentiment
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)

# %%
# !pip install keybert
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)

# %%
# !pip install flair
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# ...

# %%
# !pip install keyphrase_vectorizers
# Out:
# ...
#   Using cached keyphrase_vectorizers-0.0.10-py3-none-any.whl (28 kB)
# ...
#   Using cached spacy_transformers-1.1.8-py2.py3-none-any.whl (53 kB)
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)

# %%
# !pip install bertopic[spacy]
# Out:
# ...
#   Using cached bertopic-0.12.0-py2.py3-none-any.whl (90 kB)
# ...
#   Using cached umap_learn-0.5.3-py3-none-any.whl
# ...
#   Using cached PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# ...
#   Using cached hdbscan-0.8.28.tar.gz (5.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached pynndescent-0.5.7-py3-none-any.whl
# ...
#   Using cached numpy-1.20.3-cp39-cp39-win_amd64.whl (13.7 MB)
# ...
# Failed to build hdbscan
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
# ...

# %%
# !pip install tweepy
# Out:
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.26.0
#     Uninstalling requests-2.26.0:
#       Successfully uninstalled requests-2.26.0
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# ...

# %%
import pandas as pd
#from bertopic import BERTopic
import text2emotion as te
from textblob_de import TextBlobDE
from germansentiment import SentimentModel
from keybert import KeyBERT
from flair.embeddings import TransformerDocumentEmbeddings
from keyphrase_vectorizers import KeyphraseCountVectorizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
import spacy
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import tweepy
import pandas as pd
import re
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
import nltk
nltk.download('vader_lexicon')

import numpy as np
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
from textblob import TextBlob
import tweepy
import sys

# %% [markdown]
# # Twiiter API Configuration

# %%
# IF WE HAVE A FILE IN WHICH OUR TWITTER KEYS ARE STORED (UNCOMENT THE FOLLOWING CHUNK OF CODE)--------------------

# mykeys=open('twitterkeys.txt','r').read().splitlines
# api_key=mykeys[0]
# api_key_sceret=mykeys[1]
# access_token=mykeys[2]
# access_token_sceret=mykeys[3]

# OR IF WE WANT TO PUT ALL THE VALUES BY OURSELF (UNCOMENT THE FOLLOWING CHUNK OF CODE AND FILL UP THE VALUES)---------------------
api_key='Z5BSrN3CXE8UtxQl6lvqvNo0B'
api_key_secret='sy5Ilv0Y96kn2VldjDDhKCDP7A8wjnYO14uKQAKqOZGUvPp5ig'
access_token='1560614486452539392-CREddsSuP0Zl8JasBaQvA52dyuesRW'
access_token_secret='CEh4KgbcBefAVoVVkBjzEmLCpJQRJl74ynJCwyvPP15Y6'

# %%
from tweepy.auth import OAuthHandler
auth_handler=tweepy.OAuthHandler(consumer_key=api_key, consumer_secret=api_key_secret)
auth_handler.set_access_token(access_token, access_token_secret)
api=tweepy.API(auth_handler)

# %% [markdown]
# # Twitter Authentication

# %%
#Put your Bearer Token in the parenthesis below
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAPtVgwEAAAAArpefImIEY%2FD5A2qNPC9PsBsj334%3Dv8towNQzEL6iij26VwMaNvE8nNcUZJh6GtuwEXkeMghLJp43Ox')

# %% [markdown]
# # Get recent public tweets on a Keyword

# %%
query = '#Windenergie -is:retweet lang:de' ,
'#Hessen Windenergie -is:retweet lang:de',
'#Hessen Windkraft -is:retweet lang:de', 
'#Hessen Windanlage -is:retweet lang:de' , 
'#Hessen Windpark -is:retweet lang:de', 
'#Hessen Windrad -is:retweet lang:de' ,
'#Hessen Photovoltaik -is:retweet lang:de',
'#Hessen Photovoltaikpark -is:retweet lang:de',
'#Hessen Photovoltaikanlage -is:retweet lang:de',

  
paginator = tweepy.Paginator(
    client.search_recent_tweets,           # The method you want to use
    query=query,                           # Some argument for this method
    max_results=100,                       # How many tweets per page
    limit=10                               # How many pages to retrieve
)
# Get tweets that contain the hashtag #TypeKeywordHere
# -is:retweet means I don't want retweets
# lang:de is asking for the tweets to be in Deutsch

tweet_list = []

for tweet in paginator.flatten(): # Total number of tweets to retrieve
    tweet_list.append(tweet)
    print(tweet)
# Out:
# @RonaiChaker Wie sieht die Alternative in einigen Jahren ohne Nutzung der #Windenergie aus?
# Wer heute befürchtet, sein Landschaftsbild wird angeblich durch  Windräder beeinträchtigt, sollte sich mit der Alternative anfreunden
# #Klimakatastrophe ist jetzt! https://t.co/ZZLSI1rnn2
# Hm, die allgemeine Verblödung der rechtsextremen #AfD scheint echt rasant voranzuschreiten, wie dieses Beispiel eindrucksvoll beweist. 🥴
#
# #Klimawandel #Windenergie #JoergDornau #Leipzig #Sachsen #FakeNews #FCKAfD #FCKNZS #AfDVerbotJETZT https://t.co/gOT3CGrhYh
# Ich bin jeden Tag Dankbar das ich noch Greivögel, Fledermäuse umd Insekten erleben darf, #SL #Naturenergie und die #Stadt #Langenfeld   wollen es mit dem Ausbau der #Windenergie zerstören, #Euros  sind wichtiger.
# #Grüne Politik ist der Untergang der #Natur in Deutschland.
# Welch ein Blödsinn.
# ...

# %%
#Creating new dataframe and new features
tweet_list_df = pd.DataFrame(tweet_list)
tweet_list_df = pd.DataFrame(tweet_list_df['text'])
tweet_list_df.head(5)
# Out:
#                                                 text
# 0  @RonaiChaker Wie sieht die Alternative in eini...
# 1  Hm, die allgemeine Verblödung der rechtsextrem...
# 2  Ich bin jeden Tag Dankbar das ich noch Greivög...
# 3  Welch ein Blödsinn.\nOhne Blockade der #Photov...
# 4  Die #HamburgMesse bietet #Windenergie und #Was...

# %% [markdown]
# # Data Preprocessing

# %%
def preprocess_tweet(sen):
    '''Cleans text data up, leaving only 2 or more char long non-stepwords composed of A-Z & a-z only
    in lowercase'''
    
    sentence = sen.lower()

    # Remove RT
    sentence = re.sub('RT @\w+: '," ", sentence)

    # Remove punctuations and numbers
    sentence = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", sentence)

    # Single character removal
    sentence = re.sub(r"\s+[a-zA-Z]\s+", ' ', sentence)  # When we remove apostrophe from the word "Mark's", the apostrophe is replaced by an empty space. Hence, we are left with single character "s" that we are removing here.

    # Remove multiple spaces
    sentence = re.sub(r'\s+', ' ', sentence)  # Next, we remove all the single characters and replace it by a space which creates multiple spaces in our text. Finally, we remove the multiple spaces from our text as well.

    return sentence

# %%
cleaned_tweets = []

for tweet in tweet_list_df['text']:
  cleaned_tweet = preprocess_tweet(tweet)
  cleaned_tweets.append(cleaned_tweet)

# %%
tweet_list_df['cleaned'] = pd.DataFrame(cleaned_tweets)
tweet_list_df.head(5)
# Out:
#                                                 text  \
# 0  @RonaiChaker Wie sieht die Alternative in eini...
# 1  Hm, die allgemeine Verblödung der rechtsextrem...
# 2  Ich bin jeden Tag Dankbar das ich noch Greivög...
# 3  Welch ein Blödsinn.\nOhne Blockade der #Photov...
# 4  Die #HamburgMesse bietet #Windenergie und #Was...
#
#                                              cleaned
# 0   wie sieht die alternative in einigen jahren o...
# 1  hm die allgemeine verbl dung der rechtsextreme...
# 2  ich bin jeden tag dankbar das ich noch greiv g...
# 3  welch ein bl dsinn ohne blockade der photovolt...
# 4  die hamburgmesse bietet windenergie und wasser...

# %% [markdown]
# # Generate Sentiment Labels

# %%
tweet_list_df[['polarity', 'subjectivity']] = tweet_list_df['cleaned'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, row in tweet_list_df['cleaned'].iteritems():
    score = SentimentIntensityAnalyzer().polarity_scores(row)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    if comp <= -0.05:
        tweet_list_df.loc[index, 'sentiment'] = "negative"
    elif comp >= 0.05:
        tweet_list_df.loc[index, 'sentiment'] = "positive"
    else:
        tweet_list_df.loc[index, 'sentiment'] = "neutral"
    tweet_list_df.loc[index, 'neg'] = neg
    tweet_list_df.loc[index, 'neu'] = neu
    tweet_list_df.loc[index, 'pos'] = pos
    tweet_list_df.loc[index, 'compound'] = comp

tweet_list_df.head(5)
# Out:
#                                                 text  \
# 0  @RonaiChaker Wie sieht die Alternative in eini...
# 1  Hm, die allgemeine Verblödung der rechtsextrem...
# 2  Ich bin jeden Tag Dankbar das ich noch Greivög...
# 3  Welch ein Blödsinn.\nOhne Blockade der #Photov...
# 4  Die #HamburgMesse bietet #Windenergie und #Was...
#
#                                              cleaned  polarity  subjectivity  \
# 0   wie sieht die alternative in einigen jahren o...       0.0           0.0
# 1  hm die allgemeine verbl dung der rechtsextreme...       0.0           0.0
# 2  ich bin jeden tag dankbar das ich noch greiv g...       0.0           0.0
# 3  welch ein bl dsinn ohne blockade der photovolt...       0.0           0.0
# 4  die hamburgmesse bietet windenergie und wasser...       0.0           0.0
#
#   sentiment    neg    neu    pos  compound
# 0  negative  0.106  0.894  0.000   -0.5994
# 1  negative  0.135  0.865  0.000   -0.5994
# 2  negative  0.083  0.917  0.000   -0.5994
# ...

# %% [markdown]
# # Sentiment Visualisation

# %%
#Creating new data frames for all sentiments (positive, negative and neutral)

tweet_list_df_negative = tweet_list_df[tweet_list_df["sentiment"]=="negative"]
tweet_list_df_positive = tweet_list_df[tweet_list_df["sentiment"]=="positive"]
tweet_list_df_neutral = tweet_list_df[tweet_list_df["sentiment"]=="neutral"]

# %% [markdown]
# # Donut Charts

# %%
#Function for count_values_in single columns

def count_values_in_column(data,feature):
    total=data.loc[:,feature].value_counts(dropna=False)
    percentage=round(data.loc[:,feature].value_counts(dropna=False,normalize=True)*100,2)
    return pd.concat([total,percentage],axis=1,keys=['Total','Percentage'])

# %%
#Count_values for sentiment
count_values_in_column(tweet_list_df,"sentiment")
# Out:
#           Total  Percentage
# neutral     103       49.76
# negative     95       45.89
# positive      9        4.35

# %%
# create data for Pie Chart
pichart = count_values_in_column(tweet_list_df,"sentiment")
# names= pc.index
# size=pc["Percentage"]

names= pichart.index
size=pichart["Percentage"]

# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(size, labels=names, colors=['green','blue','red'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %% [markdown]
# #Word Cloud

# %%
#from google.colab import drive
#drive.mount('/content/drive')

#%cd /content/drive/My Drive/Project9_TwitterAPI_Sentiments
#!ls

# %%
#Function to Create Wordcloud

def create_wordcloud(text):
   # Create and Generate a Word Cloud Image
    wordcloud = WordCloud().generate(text)
#Display the generated image
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.figure(figsize=[8,10])
    plt.axis("off")

# %%
# Creating wordcloud for all tweets

create_wordcloud(str(tweet_list_df["cleaned"].values))
create_wordcloud(str(tweet_list_df_positive["cleaned"].values))
create_wordcloud(str(tweet_list_df_negative["cleaned"].values))
create_wordcloud(str(tweet_list_df_neutral["cleaned"].values))

# %% [markdown]
# #Text Insights

# %%
#Calculating tweet's lenght and word count
tweet_list_df['text_len'] = tweet_list_df['cleaned'].astype(str).apply(len)
tweet_list_df['text_word_count'] = tweet_list_df['cleaned'].apply(lambda x: len(str(x).split()))

# %%
round(pd.DataFrame(tweet_list_df.groupby("sentiment").text_len.mean()),2)
# Out:
#            text_len
# sentiment
# negative     212.64
# neutral      159.69
# positive     179.22

# %%
round(pd.DataFrame(tweet_list_df.groupby("sentiment").text_word_count.mean()),2)
# Out:
#            text_word_count
# sentiment
# negative             31.60
# neutral              20.99
# positive             23.22

# %% [markdown]
# # Saving Output Tweets File to Drive

# %%
tweet_list_df.to_csv("./c2_sentimentanalysis_output.csv", sep=',', encoding='UTF-8')
tweet_list_df.head(5)
# Out:
#                                                 text  \
# 0  @RonaiChaker Wie sieht die Alternative in eini...
# 1  Hm, die allgemeine Verblödung der rechtsextrem...
# 2  Ich bin jeden Tag Dankbar das ich noch Greivög...
# 3  Welch ein Blödsinn.\nOhne Blockade der #Photov...
# 4  Die #HamburgMesse bietet #Windenergie und #Was...
#
#                                              cleaned  polarity  subjectivity  \
# 0   wie sieht die alternative in einigen jahren o...       0.0           0.0
# 1  hm die allgemeine verbl dung der rechtsextreme...       0.0           0.0
# 2  ich bin jeden tag dankbar das ich noch greiv g...       0.0           0.0
# 3  welch ein bl dsinn ohne blockade der photovolt...       0.0           0.0
# 4  die hamburgmesse bietet windenergie und wasser...       0.0           0.0
#
#   sentiment    neg    neu    pos  compound  text_len  text_word_count
# 0  negative  0.106  0.894  0.000   -0.5994       236               34
# ...

# %% [markdown]
# ### Clustering

# %%
tweet_list_df['cleaned']
# Out:
# 0       wie sieht die alternative in einigen jahren o...
# 1      hm die allgemeine verbl dung der rechtsextreme...
# 2      ich bin jeden tag dankbar das ich noch greiv g...
# 3      welch ein bl dsinn ohne blockade der photovolt...
# 4      die hamburgmesse bietet windenergie und wasser...
#                              ...
# 202    eologix erh lt millioneninvestment r weiteres ...
# 203     charts wasserstoff ist ideal um windenergie a...
# 204     offshore windenergie rwe bekommt zuschlag r 9...
# 205    es tut sich was bei offshorewind die bnetza ha...
# 206    olaf so b schen nordischer wikinger is ja auch...
# Name: cleaned, Length: 207, dtype: object

# %%
#defining function for tokenization
import re
def tokenization(text):
    tokens = re.split('\s',text)
    return tokens
#applying function to the column
tweet_list_df['tokenied']= tweet_list_df['cleaned'].apply(lambda x: tokenization(x))
tweet_list_df.head()
# Out:
#                                                 text  \
# 0  @RonaiChaker Wie sieht die Alternative in eini...
# 1  Hm, die allgemeine Verblödung der rechtsextrem...
# 2  Ich bin jeden Tag Dankbar das ich noch Greivög...
# 3  Welch ein Blödsinn.\nOhne Blockade der #Photov...
# 4  Die #HamburgMesse bietet #Windenergie und #Was...
#
#                                              cleaned  polarity  subjectivity  \
# 0   wie sieht die alternative in einigen jahren o...       0.0           0.0
# 1  hm die allgemeine verbl dung der rechtsextreme...       0.0           0.0
# 2  ich bin jeden tag dankbar das ich noch greiv g...       0.0           0.0
# 3  welch ein bl dsinn ohne blockade der photovolt...       0.0           0.0
# 4  die hamburgmesse bietet windenergie und wasser...       0.0           0.0
#
#   sentiment    neg    neu    pos  compound  text_len  text_word_count  \
# 0  negative  0.106  0.894  0.000   -0.5994       236               34
# ...

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
#defining the object for Lemmatization
wordnet_lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#defining the function for lemmatization
def lemmatizer(text):
    lemm_text = [wordnet_lemmatizer.lemmatize(word) for word in text]
    return lemm_text
tweet_list_df['lemmatized']=tweet_list_df['tokenied'].apply(lambda x:lemmatizer(x))
tweet_list_df.head()
# Out:
#                                                 text  \
# 0  @RonaiChaker Wie sieht die Alternative in eini...
# 1  Hm, die allgemeine Verblödung der rechtsextrem...
# 2  Ich bin jeden Tag Dankbar das ich noch Greivög...
# 3  Welch ein Blödsinn.\nOhne Blockade der #Photov...
# 4  Die #HamburgMesse bietet #Windenergie und #Was...
#
#                                              cleaned  polarity  subjectivity  \
# 0   wie sieht die alternative in einigen jahren o...       0.0           0.0
# 1  hm die allgemeine verbl dung der rechtsextreme...       0.0           0.0
# 2  ich bin jeden tag dankbar das ich noch greiv g...       0.0           0.0
# 3  welch ein bl dsinn ohne blockade der photovolt...       0.0           0.0
# 4  die hamburgmesse bietet windenergie und wasser...       0.0           0.0
#
#   sentiment    neg    neu    pos  compound  text_len  text_word_count  \
# 0  negative  0.106  0.894  0.000   -0.5994       236               34
# ...

# %%
import itertools

merged = list(itertools.chain(*tweet_list_df['lemmatized']))
merged
# Out:
# ['',
#  'wie',
#  'sieht',
#  'die',
#  'alternative',
#  'in',
#  'einigen',
#  'jahren',
#  'ohne',
#  'nutzung',
#  'der',
#  'windenergie',
#  'au',
#  'wer',
#  'heute',
#  'bef',
#  'rchtet',
#  'sein',
#  'landschaftsbild',
#  'wird',
#  'angeblich',
#  'durch',
#  'windr',
#  'der',
#  'beeintr',
#  'chtigt',
#  'sollte',
#  'sich',
#  'mit',
#  'der',
#  'alternative',
#  'anfreunden',
#  'klimakatastrophe',
#  'ist',
#  'jetzt',
#  '',
#  'hm',
#  'die',
#  'allgemeine',
#  'verbl',
#  'dung',
#  'der',
#  'rechtsextremen',
#  'afd',
#  'scheint',
#  'echt',
#  'rasant',
#  'voranzuschreiten',
#  'wie',
#  'diesis',
#  'beispiel',
#  'eindrucksvoll',
#  'beweist',
#  'klimawandel',
#  'windenergie',
#  'joergdornau',
#  'leipzig',
#  'sachsen',
#  'fakenews',
#  'fckafd',
#  'fcknzs',
#  'afdverbotjetzt',
#  '',
#  'ich',
#  'bin',
#  'jeden',
#  'tag',
#  'dankbar',
#  'da',
#  'ich',
#  'noch',
#  'greiv',
#  'gel',
#  'flederm',
#  'use',
#  'umd',
#  'insekten',
# ...

# %%
import pandas as pd
import re
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt




cv = CountVectorizer(analyzer = 'word', max_features = 5000, lowercase=True, preprocessor=None, tokenizer=None, stop_words = stopwords.words('german'))  
vectors = cv.fit_transform(merged)
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 0)
kmean_indices = kmeans.fit_predict(vectors)

pca = PCA(n_components=2)
scatter_plot_points = pca.fit_transform(vectors.toarray())

colors = ["r", "b", "c", "y", "m" ]

x_axis = [o[0] for o in scatter_plot_points]
y_axis = [o[1] for o in scatter_plot_points]
fig, ax = plt.subplots(figsize=(20,10))

ax.scatter(x_axis, y_axis, c=[colors[d] for d in kmean_indices])

for i, txt in enumerate(merged):
    ax.annotate(txt, (x_axis[i], y_axis[i]))

# %%
#This method returns the tweet corressponding to the given search word and the amount of tweet 

# def search(search_term, tweet_amount):
  
#   # For Example:
#   # search_terms= 'Windenergie' 
#   # tweet_amount=100

#   tweets=tweepy.cursor(api.search, q=search_term, lang='de').items(tweet_amount)

  

#   for tweet in tweets:

#     #cleaning
#     final_text=tweet.text.replace('RT', '')
#     if final_text.strartswith(' @'):
#       position=final_text.index(':')
#       final_text=final_text[position+2]
#     if final_text.strartswith('@'):
#       position=final_text.index(' ')
#       final_text=final_text[position+2]
#     return final_text

#   # positive=0
#   # negative=0
#   # neutral=0

#   # #counting positive, negative or neutral tweets
#   #   if tweet_polarity>0.00:
#   #     positive+=1
#   #   elif tweet_polarity<0.00:
#   #     negative+=1
#   #   elif tweet_polarity==0.00:
#   #     neutral+=1

  #   polarity+=tweet_polarity
  #   polarity+=analysis.polarity
  #   print(final_text)


  # print(polarity) #a positive number means that tweets are positive overall, and simliar with negative 
  # print(f'Amount of postive tweets: {positive}')
  # print(f'Amount of negative tweets: {negative}')
  # print(f'Amount of neutral tweets: {neutral}')

# %% [markdown]
# ## Helper

# %%
def get_sections(text):
    spacy_text = nlp(text)
    return spacy_text.text.split("\n\n")

def get_sentences(text):
    spacy_text = nlp(text)
    sents = []
    for sent in spacy_text.sents:
        sents.append(sent.text)
    return sents

def remove_stopwords(text):
    if(str(text) == "nan"):
        return None
    spacy_text = nlp(text)
    return ' '.join([str(t) for t in spacy_text if not t.is_stop])

# (Comment)suggested code, can be easily done operations on. The idea behind this is, for doing easy operations it is easier if the data is in an array. but if u don't want it to be in an array u can also have it as doc by just adding the line 'return ' '.join(tokenize_words_without_stop_words)' instead of print statement 

# def remove_stopwords(text):
#   from nltk import tokenize
#   stop_words=set(stopwords.words('german'))
#   from nltk.tokenize import  word_tokenize,sent_tokenize
#   tokenize_words=word_tokenize(text)
#   tokenize_words_without_stop_words=[]
#   for word in tokenize_words:
#     if word not in stop_words:
#       tokenize_words_without_stop_words.append(word)
#   return tokenize_words_without_stop_words

# (Comment)This code is used for lemmantization, for normal operations the above 'remove_stopwords(text)' function will be used (cause they are in arrays) rather than the function below. (That is why as you can check in lemmantizer fucntion the below function is used)

# def remove_stopwords2(text):
#   from nltk import tokenize
#   stop_words=set(stopwords.words('german'))
#   from nltk.tokenize import  word_tokenize,sent_tokenize
#   tokenize_words=word_tokenize(text)
#   tokenize_words_without_stop_words=[]
#   for word in tokenize_words:
#     if word not in stop_words:
#       tokenize_words_without_stop_words.append(word)
#   return ' '.join(tokenize_words_without_stop_words)

def lemmatizer(text):
    spacy_text = nlp(text)
    text_whithout_stopwords = []
    for token in spacy_text.doc:
        if(token.is_alpha):
            text_whithout_stopwords.append(token.lemma_)
    return " ".join(text_whithout_stopwords)

# (Comment)In the previous code the stopwords was not removed, so i added that by calling remove_stopwords function.

# def lemmatizer(text):
#     spacy_text=remove_stopwords2(text) 
#     doc=nlp(spacy_text)
#     text_whithout_stopwords = []
#     for token in doc:
#         if not token.is_punct:
#             text_whithout_stopwords.append(token.lemma_)
#     return ' '.join(text_whithout_stopwords)

# %% [markdown]
# # Comparison

# %%
def compare_texts_cleaned(comp_a, comp_b):
    if max([len(comp_a), len(comp_b)]) == 0:
        return 0
    comp_a = set(lemmatizer(remove_stopwords(comp_a)).split())
    comp_b = set(lemmatizer(remove_stopwords(comp_b)).split())
    return len(comp_a.intersection(comp_b)) / max([len(comp_a), len(comp_b)])

def compare_texts(comp_a, comp_b):
    if max([len(comp_a), len(comp_b)]) == 0:
        return 0
    comp_a = set(lemmatizer(comp_a).split())
    comp_b = set(lemmatizer(comp_b).split())
    return len(comp_a.intersection(comp_b)) / max([len(comp_a), len(comp_b)])

def compare_text_meaning(comp_a, comp_b):
    comp_a = nlp(comp_a)
    comp_b = nlp(comp_b)
    return comp_a.similarity(comp_b)

def compare_text_meaning_cleaned(comp_a, comp_b):
    comp_a = nlp(comp_a)
    comp_b = nlp(comp_b)
    comp_a = nlp(' '.join([str(t) for t in comp_a if not t.is_stop]))
    comp_b = nlp(' '.join([str(t) for t in comp_b if not t.is_stop]))
    return comp_a.similarity(comp_b)
